# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Step 2: Install FiftyOne
# !pip install fiftyone
# Out:
# Mounted at /content/drive
# Collecting fiftyone
#   Downloading fiftyone-1.7.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.11/dist-packages (from fiftyone) (24.1.0)
# Collecting argcomplete (from fiftyone)
#   Downloading argcomplete-3.6.2-py3-none-any.whl.metadata (16 kB)
# Collecting async_lru>=2 (from fiftyone)
#   Downloading async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from fiftyone) (4.13.4)
# Collecting boto3 (from fiftyone)
#   Downloading boto3-1.40.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from fiftyone) (5.5.2)
# Collecting dacite<1.8.0,>=1.6.0 (from fiftyone)
#   Downloading dacite-1.7.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from fiftyone) (0.3.8)
# Collecting Deprecated (from fiftyone)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting ftfy (from fiftyone)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from fiftyone) (4.12.3)
# Collecting hypercorn>=0.13.2 (from fiftyone)
#   Downloading hypercorn-0.17.3-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: Jinja2>=3 in /usr/local/lib/python3.11/dist-packages (from fiftyone) (3.1.6)
# Collecting kaleido!=0.2.1.post1 (from fiftyone)
#   Downloading kaleido-1.0.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from fiftyone) (3.10.0)
# Collecting mongoengine~=0.29.1 (from fiftyone)
#   Downloading mongoengine-0.29.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting motor~=3.6.0 (from fiftyone)
#   Downloading motor-3.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from fiftyone) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from fiftyone) (25.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from fiftyone) (2.2.2)
# Requirement already satisfied: Pillow>=6.2 in /usr/local/lib/python3.11/dist-packages (from fiftyone) (11.3.0)
# Requirement already satisfied: plotly>=4.14 in /usr/local/lib/python3.11/dist-packages (from fiftyone) (5.24.1)
# Collecting pprintpp (from fiftyone)
#   Downloading pprintpp-0.4.0-py2.py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from fiftyone) (5.9.5)
# Collecting pymongo~=4.9.2 (from fiftyone)
#   Downloading pymongo-4.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from fiftyone) (2025.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from fiftyone) (6.0.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from fiftyone) (2024.11.6)
# Collecting retrying (from fiftyone)
#   Downloading retrying-1.4.1-py3-none-any.whl.metadata (7.5 kB)
# Collecting rtree (from fiftyone)
#   Downloading rtree-1.4.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from fiftyone) (1.6.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from fiftyone) (0.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from fiftyone) (1.16.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from fiftyone) (75.2.0)
# Collecting sseclient-py<2,>=1.7.2 (from fiftyone)
#   Downloading sseclient_py-1.8.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting sse-starlette<1,>=0.10.3 (from fiftyone)
#   Downloading sse_starlette-0.10.3-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: starlette>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from fiftyone) (0.47.2)
# Collecting strawberry-graphql>=0.262.4 (from fiftyone)
#   Downloading strawberry_graphql-0.278.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from fiftyone) (0.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from fiftyone) (4.67.1)
# Collecting xmltodict (from fiftyone)
#   Downloading xmltodict-0.14.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting universal-analytics-python3<2,>=1.0.1 (from fiftyone)
#   Downloading universal_analytics_python3-1.1.1-py3-none-any.whl.metadata (5.5 kB)
# Collecting pydash (from fiftyone)
#   Downloading pydash-8.0.5-py3-none-any.whl.metadata (4.5 kB)
# Collecting fiftyone-brain<0.22,>=0.21.2 (from fiftyone)
#   Downloading fiftyone_brain-0.21.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting fiftyone-db<2.0,>=0.4 (from fiftyone)
#   Downloading fiftyone_db-1.3.0.tar.gz (8.2 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting voxel51-eta<0.15,>=0.14.2 (from fiftyone)
#   Downloading voxel51_eta-0.14.3-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (from fiftyone) (4.12.0.88)
# Requirement already satisfied: h11 in /usr/local/lib/python3.11/dist-packages (from hypercorn>=0.13.2->fiftyone) (0.16.0)
# Requirement already satisfied: h2>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from hypercorn>=0.13.2->fiftyone) (4.2.0)
# Collecting priority (from hypercorn>=0.13.2->fiftyone)
#   Downloading priority-2.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting wsproto>=0.14.0 (from hypercorn>=0.13.2->fiftyone)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3->fiftyone) (3.0.2)
# Collecting choreographer>=1.0.5 (from kaleido!=0.2.1.post1->fiftyone)
#   Downloading choreographer-1.0.9-py3-none-any.whl.metadata (5.6 kB)
# Collecting logistro>=1.0.8 (from kaleido!=0.2.1.post1->fiftyone)
#   Downloading logistro-1.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: orjson>=3.10.15 in /usr/local/lib/python3.11/dist-packages (from kaleido!=0.2.1.post1->fiftyone) (3.11.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=4.14->fiftyone) (8.5.0)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo~=4.9.2->fiftyone)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette>=0.24.0->fiftyone) (4.9.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from starlette>=0.24.0->fiftyone) (4.14.1)
# Collecting graphql-core<3.4.0,>=3.2.0 (from strawberry-graphql>=0.262.4->fiftyone)
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: python-dateutil<3.0,>=2.7 in /usr/local/lib/python3.11/dist-packages (from strawberry-graphql>=0.262.4->fiftyone) (2.9.0.post0)
# Requirement already satisfied: httpx>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from universal-analytics-python3<2,>=1.0.1->fiftyone) (0.28.1)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (1.0.0)
# Requirement already satisfied: glob2 in /usr/local/lib/python3.11/dist-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (0.7)
# Collecting jsonlines (from voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting py7zr (from voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Downloading py7zr-1.0.0-py3-none-any.whl.metadata (17 kB)
# Collecting rarfile (from voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Downloading rarfile-4.2-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (1.17.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (2.4.0)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.11/dist-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (5.3.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (2.5.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->fiftyone) (2.7)
# Collecting botocore<1.41.0,>=1.40.0 (from boto3->fiftyone)
#   Downloading botocore-1.40.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->fiftyone)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.14.0,>=0.13.0 (from boto3->fiftyone)
#   Downloading s3transfer-0.13.1-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from Deprecated->fiftyone) (1.17.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy->fiftyone) (0.2.13)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->fiftyone) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->fiftyone) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->fiftyone) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->fiftyone) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->fiftyone) (3.2.3)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->fiftyone) (2025.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image->fiftyone) (3.5)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->fiftyone) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->fiftyone) (2025.6.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->fiftyone) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->fiftyone) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->fiftyone) (3.6.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette>=0.24.0->fiftyone) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette>=0.24.0->fiftyone) (1.3.1)
# Requirement already satisfied: simplejson>=3.19.3 in /usr/local/lib/python3.11/dist-packages (from choreographer>=1.0.5->kaleido!=0.2.1.post1->fiftyone) (3.20.1)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.11/dist-packages (from h2>=3.1.0->hypercorn>=0.13.2->fiftyone) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.11/dist-packages (from h2>=3.1.0->hypercorn>=0.13.2->fiftyone) (4.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (1.0.9)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonlines->voxel51-eta<0.15,>=0.14.2->fiftyone) (25.3.0)
# Collecting texttable (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: pycryptodomex>=3.20.0 in /usr/local/lib/python3.11/dist-packages (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone) (3.23.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone) (1.1.0)
# Collecting pyzstd>=0.16.1 (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Downloading pyzstd-0.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting pyppmd<1.3.0,>=1.1.0 (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Downloading pyppmd-1.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting pybcj<1.1.0,>=1.0.0 (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Downloading pybcj-1.0.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Collecting multivolumefile>=0.2.3 (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Downloading multivolumefile-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting inflate64<1.1.0,>=1.0.0 (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Downloading inflate64-1.0.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->voxel51-eta<0.15,>=0.14.2->fiftyone) (3.4.2)
# Downloading fiftyone-1.7.1-py3-none-any.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 49.8 MB/s eta 0:00:00
# Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Downloading dacite-1.7.0-py3-none-any.whl (12 kB)
# Downloading fiftyone_brain-0.21.2-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 kB 8.5 MB/s eta 0:00:00
# Downloading hypercorn-0.17.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 4.8 MB/s eta 0:00:00
# Downloading kaleido-1.0.0-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 4.2 MB/s eta 0:00:00
# Downloading mongoengine-0.29.1-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 7.4 MB/s eta 0:00:00
# Downloading motor-3.6.1-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 5.9 MB/s eta 0:00:00
# Downloading pymongo-4.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 42.4 MB/s eta 0:00:00
# Downloading sse_starlette-0.10.3-py3-none-any.whl (8.0 kB)
# Downloading sseclient_py-1.8.0-py2.py3-none-any.whl (8.8 kB)
# Downloading strawberry_graphql-0.278.0-py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.0/310.0 kB 23.1 MB/s eta 0:00:00
# Downloading universal_analytics_python3-1.1.1-py3-none-any.whl (10 kB)
# Downloading voxel51_eta-0.14.3-py2.py3-none-any.whl (943 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 943.3/943.3 kB 46.2 MB/s eta 0:00:00
# Downloading argcomplete-3.6.2-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 3.6 MB/s eta 0:00:00
# Downloading boto3-1.40.0-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 11.7 MB/s eta 0:00:00
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.2 MB/s eta 0:00:00
# Downloading pprintpp-0.4.0-py2.py3-none-any.whl (16 kB)
# Downloading pydash-8.0.5-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.1/102.1 kB 7.0 MB/s eta 0:00:00
# Downloading retrying-1.4.1-py3-none-any.whl (12 kB)
# Downloading rtree-1.4.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (541 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 541.1/541.1 kB 22.8 MB/s eta 0:00:00
# Downloading xmltodict-0.14.2-py2.py3-none-any.whl (10.0 kB)
# Downloading botocore-1.40.0-py3-none-any.whl (13.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 48.3 MB/s eta 0:00:00
# Downloading choreographer-1.0.9-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 kB 4.3 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 18.8 MB/s eta 0:00:00
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 11.2 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading logistro-1.1.0-py3-none-any.whl (7.9 kB)
# Downloading s3transfer-0.13.1-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 7.3 MB/s eta 0:00:00
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading priority-2.0.0-py3-none-any.whl (8.9 kB)
# Downloading py7zr-1.0.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 kB 5.8 MB/s eta 0:00:00
# Downloading rarfile-4.2-py3-none-any.whl (29 kB)
# Downloading inflate64-1.0.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 7.8 MB/s eta 0:00:00
# Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Downloading pybcj-1.0.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 3.6 MB/s eta 0:00:00
# Downloading pyppmd-1.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.3/141.3 kB 11.6 MB/s eta 0:00:00
# Downloading pyzstd-0.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (412 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.9/412.9 kB 25.5 MB/s eta 0:00:00
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: fiftyone-db
#   Building wheel for fiftyone-db (pyproject.toml) ... done
#   Created wheel for fiftyone-db: filename=fiftyone_db-1.3.0-py3-none-manylinux1_x86_64.whl size=42156245 sha256=dfd471f38e521d81d62becb0f4e12a257450d04a99ad0ee4b9cfa067c81e20bd
#   Stored in directory: /root/.cache/pip/wheels/4d/42/2f/67d2c5896157c73671b965144411c2e39148aa27b66833993d
# Successfully built fiftyone-db
# Installing collected packages: texttable, sseclient-py, pprintpp, xmltodict, wsproto, rtree, retrying, rarfile, pyzstd, pyppmd, pydash, pybcj, priority, multivolumefile, logistro, jsonlines, jmespath, inflate64, graphql-core, ftfy, fiftyone-db, dnspython, Deprecated, dacite, async_lru, argcomplete, strawberry-graphql, pymongo, py7zr, hypercorn, choreographer, botocore, voxel51-eta, universal-analytics-python3, sse-starlette, s3transfer, motor, mongoengine, kaleido, fiftyone-brain, boto3, fiftyone
# Successfully installed Deprecated-1.2.18 argcomplete-3.6.2 async_lru-2.0.5 boto3-1.40.0 botocore-1.40.0 choreographer-1.0.9 dacite-1.7.0 dnspython-2.7.0 fiftyone-1.7.1 fiftyone-brain-0.21.2 fiftyone-db-1.3.0 ftfy-6.3.1 graphql-core-3.2.6 hypercorn-0.17.3 inflate64-1.0.3 jmespath-1.0.1 jsonlines-4.0.0 kaleido-1.0.0 logistro-1.1.0 mongoengine-0.29.1 motor-3.6.1 multivolumefile-0.2.3 pprintpp-0.4.0 priority-2.0.0 py7zr-1.0.0 pybcj-1.0.6 pydash-8.0.5 pymongo-4.9.2 pyppmd-1.2.0 pyzstd-0.17.0 rarfile-4.2 retrying-1.4.1 rtree-1.4.0 s3transfer-0.13.1 sse-starlette-0.10.3 sseclient-py-1.8.0 strawberry-graphql-0.278.0 texttable-1.7.0 universal-analytics-python3-1.1.1 voxel51-eta-0.14.3 wsproto-1.2.0 xmltodict-0.14.2

# %%
# Step 3: Load the datasets
import fiftyone as fo
import fiftyone.types as fot

# %%
dataset1_dir = "/content/drive/MyDrive/FoodWasteHackathon_BIBI/Dataset/food_waste_part_1"
dataset2_dir = "/content/drive/MyDrive/FoodWasteHackathon_BIBI/Dataset/FiftyOne_dataset_part2"

# %%
# List all loaded datasets
all_datasets = fo.list_datasets()
print("Datasets found:", all_datasets)

# Delete each one
for name in all_datasets:
    print(f"Deleting dataset: {name}")
    fo.delete_dataset(name)
# Out:
# Datasets found: ['loaded_dataset_1', 'loaded_dataset_2']
# Deleting dataset: loaded_dataset_1
# Deleting dataset: loaded_dataset_2

# %%
import fiftyone as fo

# Load from exported directories (FiftyOne format)
dataset1 = fo.Dataset.from_dir(
    dataset_dir=dataset1_dir,
    dataset_type=fo.types.FiftyOneDataset,
    name="loaded_dataset_1"
)

dataset2 = fo.Dataset.from_dir(
    dataset_dir=dataset2_dir,
    dataset_type=fo.types.FiftyOneDataset,
    name="loaded_dataset_2"
)
def print_fields_with_types(dataset, name):
    print(f"\n{name} fields:")
    for field_name, field in dataset.get_field_schema().items():
        print(f"  {field_name}: {type(field)}")

# Print schemas
print_fields_with_types(dataset1, "Dataset 1")
print_fields_with_types(dataset2, "Dataset 2")
# Out:
# Importing samples...
# INFO:fiftyone.utils.data.importers:Importing samples...
#  100% |█████████████████| 375/375 [68.1ms elapsed, 0s remaining, 5.5K samples/s]
# INFO:eta.core.utils: 100% |█████████████████| 375/375 [68.1ms elapsed, 0s remaining, 5.5K samples/s]
# Importing samples...
# INFO:fiftyone.utils.data.importers:Importing samples...
#  100% |█████████████████| 255/255 [49.7ms elapsed, 0s remaining, 5.1K samples/s]
# INFO:eta.core.utils: 100% |█████████████████| 255/255 [49.7ms elapsed, 0s remaining, 5.1K samples/s]
# Dataset 1 fields:
#   id: <class 'fiftyone.core.fields.ObjectIdField'>
#   filepath: <class 'fiftyone.core.fields.StringField'>
#   tags: <class 'fiftyone.core.fields.ListField'>
#   metadata: <class 'fiftyone.core.fields.EmbeddedDocumentField'>
#   created_at: <class 'fiftyone.core.fields.DateTimeField'>
#   last_modified_at: <class 'fiftyone.core.fields.DateTimeField'>
#   split: <class 'fiftyone.core.fields.StringField'>
#   bonid: <class 'fiftyone.core.fields.IntField'>
#   bon_id: <class 'fiftyone.core.fields.ListField'>
#   article_number: <class 'fiftyone.core.fields.ListField'>
#   ingredient_name: <class 'fiftyone.core.fields.ListField'>
#   piece_article: <class 'fiftyone.core.fields.ListField'>
#   number_of_portions: <class 'fiftyone.core.fields.ListField'>
#   weight_per_portion: <class 'fiftyone.core.fields.ListField'>
#   weight_per_plate: <class 'fiftyone.core.fields.ListField'>
#   kcal_per_plate: <class 'fiftyone.core.fields.ListField'>
#   kj_per_plate: <class 'fiftyone.core.fields.ListField'>
#   fat_per_plate: <class 'fiftyone.core.fields.ListField'>
#   saturated_fat_per_plate: <class 'fiftyone.core.fields.ListField'>
#   carbohydrates_per_plate: <class 'fiftyone.core.fields.ListField'>
#   sugar_per_plate: <class 'fiftyone.core.fields.ListField'>
#   protein_per_plate: <class 'fiftyone.core.fields.ListField'>
#   salt_per_plate: <class 'fiftyone.core.fields.ListField'>
#   return_quantity: <class 'fiftyone.core.fields.ListField'>
#   return_percentage: <class 'fiftyone.core.fields.ListField'>
#   dish: <class 'fiftyone.core.fields.StringField'>
#   portion_size: <class 'fiftyone.core.fields.StringField'>
#   weight_before: <class 'fiftyone.core.fields.IntField'>
#   kcal_before: <class 'fiftyone.core.fields.StringField'>
#   kj_before: <class 'fiftyone.core.fields.StringField'>
#   fat_before: <class 'fiftyone.core.fields.StringField'>
#   saturated_fat_before: <class 'fiftyone.core.fields.StringField'>
#   carbohydrates_before: <class 'fiftyone.core.fields.StringField'>
#   sugar_before: <class 'fiftyone.core.fields.StringField'>
#   protein_before: <class 'fiftyone.core.fields.StringField'>
#   salt_before: <class 'fiftyone.core.fields.StringField'>
#   weight_after: <class 'fiftyone.core.fields.IntField'>
#   kcal_after: <class 'fiftyone.core.fields.StringField'>
#   kj_after: <class 'fiftyone.core.fields.StringField'>
#   fat_after: <class 'fiftyone.core.fields.StringField'>
#   saturated_fat_after: <class 'fiftyone.core.fields.StringField'>
#   carbohydrates_after: <class 'fiftyone.core.fields.StringField'>
#   sugar_after: <class 'fiftyone.core.fields.StringField'>
#   protein_after: <class 'fiftyone.core.fields.StringField'>
#   salt_after: <class 'fiftyone.core.fields.StringField'>
#   yoloe_segmentation: <class 'fiftyone.core.fields.EmbeddedDocumentField'>
#   dinov2-image-embeddings: <class 'fiftyone.core.fields.VectorField'>
#   dinov2-vitl4-embeddings: <class 'fiftyone.core.fields.VectorField'>
#
# Dataset 2 fields:
#   id: <class 'fiftyone.core.fields.ObjectIdField'>
#   filepath: <class 'fiftyone.core.fields.StringField'>
#   tags: <class 'fiftyone.core.fields.ListField'>
#   metadata: <class 'fiftyone.core.fields.EmbeddedDocumentField'>
#   created_at: <class 'fiftyone.core.fields.DateTimeField'>
#   last_modified_at: <class 'fiftyone.core.fields.DateTimeField'>
#   split: <class 'fiftyone.core.fields.StringField'>
#   bonid: <class 'fiftyone.core.fields.IntField'>
#   bon_id: <class 'fiftyone.core.fields.ListField'>
#   article_number: <class 'fiftyone.core.fields.ListField'>
#   ingredient_name: <class 'fiftyone.core.fields.ListField'>
#   piece_article: <class 'fiftyone.core.fields.ListField'>
#   number_of_portions: <class 'fiftyone.core.fields.ListField'>
#   weight_per_portion: <class 'fiftyone.core.fields.ListField'>
#   weight_per_plate: <class 'fiftyone.core.fields.ListField'>
#   kcal_per_plate: <class 'fiftyone.core.fields.ListField'>
#   kj_per_plate: <class 'fiftyone.core.fields.ListField'>
#   fat_per_plate: <class 'fiftyone.core.fields.ListField'>
#   saturated_fat_per_plate: <class 'fiftyone.core.fields.ListField'>
#   carbohydrates_per_plate: <class 'fiftyone.core.fields.ListField'>
#   sugar_per_plate: <class 'fiftyone.core.fields.ListField'>
#   protein_per_plate: <class 'fiftyone.core.fields.ListField'>
#   salt_per_plate: <class 'fiftyone.core.fields.ListField'>
#   return_quantity: <class 'fiftyone.core.fields.ListField'>
#   return_percentage: <class 'fiftyone.core.fields.ListField'>
#   dish: <class 'fiftyone.core.fields.StringField'>
#   portion_size: <class 'fiftyone.core.fields.StringField'>
#   weight_before: <class 'fiftyone.core.fields.IntField'>
#   kcal_before: <class 'fiftyone.core.fields.FloatField'>
#   kj_before: <class 'fiftyone.core.fields.FloatField'>
#   fat_before: <class 'fiftyone.core.fields.FloatField'>
#   saturated_fat_before: <class 'fiftyone.core.fields.FloatField'>
#   carbohydrates_before: <class 'fiftyone.core.fields.FloatField'>
#   sugar_before: <class 'fiftyone.core.fields.FloatField'>
#   protein_before: <class 'fiftyone.core.fields.FloatField'>
#   salt_before: <class 'fiftyone.core.fields.FloatField'>
#   weight_after: <class 'fiftyone.core.fields.IntField'>
#   kcal_after: <class 'fiftyone.core.fields.IntField'>
#   kj_after: <class 'fiftyone.core.fields.IntField'>
#   fat_after: <class 'fiftyone.core.fields.IntField'>
#   saturated_fat_after: <class 'fiftyone.core.fields.IntField'>
#   carbohydrates_after: <class 'fiftyone.core.fields.IntField'>
#   sugar_after: <class 'fiftyone.core.fields.IntField'>
#   protein_after: <class 'fiftyone.core.fields.IntField'>
#   salt_after: <class 'fiftyone.core.fields.IntField'>
#   yoloe_segmentation: <class 'fiftyone.core.fields.EmbeddedDocumentField'>
#   dinov2-image-embeddings: <class 'fiftyone.core.fields.VectorField'>
#   dinov2-vitl4-embeddings: <class 'fiftyone.core.fields.VectorField'>

# %%
for sample in dataset1.select_fields("kj_before").take(9):
    print(repr(sample.kj_before ))
# Out:
# '1.603,440'
# '1.603,440'
# '1.363,620'
# '1.745,200'
# '1.374,62'
# '1.475,600'
# '1.363,620'
# '1.603,440'
# '1.779,680'

# %%
import re

def euro_str_to_float(s):
    """
    Converts strings like '1.592,50' to float 1592.50
    Handles empty/None gracefully.
    """
    if s is None or (isinstance(s, str) and s.strip() == ""):
        return None
    if isinstance(s, (int, float)):
        return float(s)
    s = str(s).strip()
    # Remove thousand separators (dots), replace decimal comma with dot
    s = s.replace('.', '').replace(',', '.')
    try:
        return float(s)
    except Exception:
        return None

# %%
# 1. Make sure first assignment is a float (not None)
for sample in dataset1:
    val = sample.kcal_before
    float_val = euro_str_to_float(val)
    if float_val is not None:
        sample["kcal_before_float"] = float_val
        sample.save()
        break  # Only do this for the first convertible sample

# 2. Now do the rest (it's safe to assign None after the type is set)
for sample in dataset1:
    val = sample.kcal_before
    sample["kcal_before_float"] = euro_str_to_float(val)
    sample.save()

# %%
dataset1.delete_sample_field("kcal_before")
dataset1.rename_sample_field("kcal_before_float", "kcal_before")

# %%
fields_to_convert = {
    "kcal_before": float,
    "kj_before": float,
    "fat_before": float,
    "saturated_fat_before": float,
    "carbohydrates_before": float,
    "sugar_before": float,
    "protein_before": float,
    "salt_before": float,
    "kcal_after": int,
    "kj_after": int,
    "fat_after": int,
    "saturated_fat_after": int,
    "carbohydrates_after": int,
    "sugar_after": int,
    "protein_after": int,
    "salt_after": int,
}

def euro_str_to_float(s):
    """
    Converts European-formatted numbers as strings (e.g., '1.592,50') to float 1592.50.
    Handles None, empty, int, float, etc.
    """
    if s is None or (isinstance(s, str) and s.strip() == ""):
        return None
    if isinstance(s, (int, float)):
        return float(s)
    s = str(s).strip()
    # Remove thousand separators (dots), replace decimal comma with dot
    s = s.replace('.', '').replace(',', '.')
    try:
        return float(s)
    except Exception:
        return None

def safe_cast(val, dtype):
    num = euro_str_to_float(val)
    if num is None:
        return None
    if dtype is int:
        return int(round(num))
    return num  # float

for field, dtype in fields_to_convert.items():
    print(f"Converting {field} to {dtype}")
    temp_field = f"{field}_tmp"

    # 1. Ensure first valid (not None) value is assigned
    for sample in dataset1:
        val = sample[field]
        cast_val = safe_cast(val, dtype)
        if cast_val is not None:
            sample[temp_field] = cast_val
            sample.save()
            break  # Only need the first valid one

    # 2. Now assign to the rest (it's safe now, even for None)
    for sample in dataset1:
        val = sample[field]
        sample[temp_field] = safe_cast(val, dtype)
        sample.save()

    # 3. Delete the original field
    dataset1.delete_sample_field(field)
    # 4. Rename temp to original
    dataset1.rename_sample_field(temp_field, field)

print("All mismatched fields converted and renamed!")
# Out:
# Converting kcal_before to <class 'float'>
# Converting kj_before to <class 'float'>
# Converting fat_before to <class 'float'>
# Converting saturated_fat_before to <class 'float'>
# Converting carbohydrates_before to <class 'float'>
# Converting sugar_before to <class 'float'>
# Converting protein_before to <class 'float'>
# Converting salt_before to <class 'float'>
# Converting kcal_after to <class 'int'>
# Converting kj_after to <class 'int'>
# Converting fat_after to <class 'int'>
# Converting saturated_fat_after to <class 'int'>
# Converting carbohydrates_after to <class 'int'>
# Converting sugar_after to <class 'int'>
# Converting protein_after to <class 'int'>
# Converting salt_after to <class 'int'>
# All mismatched fields converted and renamed!

# %% [markdown]
# ## list fields dtyp

# %%
import fiftyone as fo

def print_fields_with_types_and_list_element_types(dataset, name, num_elements=3):
    print(f"\n{name} fields:")
    schema = dataset.get_field_schema()
    sample = next(iter(dataset), None)
    for field_name, field in schema.items():
        field_type = type(field)
        print(f"  {field_name}: {field_type}", end="")
        if field_type.__name__ == "ListField":
            elem_types = set()
            if sample is not None:
                lst = getattr(sample, field_name, None)
                if isinstance(lst, list) and lst:
                    elem_types = {type(x) for x in lst[:num_elements]}
            print(f"  --> element types (sample): {', '.join([t.__name__ for t in elem_types])}")
        else:
            print()

# Print schemas with element types
print_fields_with_types_and_list_element_types(dataset1, "Dataset 1")
print_fields_with_types_and_list_element_types(dataset2, "Dataset 2")
# Out:
# Dataset 1 fields:
#   id: <class 'fiftyone.core.fields.ObjectIdField'>
#   filepath: <class 'fiftyone.core.fields.StringField'>
#   tags: <class 'fiftyone.core.fields.ListField'>  --> element types (sample):
#   metadata: <class 'fiftyone.core.fields.EmbeddedDocumentField'>
#   created_at: <class 'fiftyone.core.fields.DateTimeField'>
#   last_modified_at: <class 'fiftyone.core.fields.DateTimeField'>
#   split: <class 'fiftyone.core.fields.StringField'>
#   bonid: <class 'fiftyone.core.fields.IntField'>
#   bon_id: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): int
#   article_number: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): int
#   ingredient_name: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): str
#   piece_article: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): str
#   number_of_portions: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): int
#   weight_per_portion: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): int
#   weight_per_plate: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): int
#   kcal_per_plate: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): str
#   kj_per_plate: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): str
#   fat_per_plate: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): str
#   saturated_fat_per_plate: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): str
#   carbohydrates_per_plate: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): str
#   sugar_per_plate: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): str
#   protein_per_plate: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): str
#   salt_per_plate: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): str
#   return_quantity: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): float
#   return_percentage: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): float
#   dish: <class 'fiftyone.core.fields.StringField'>
#   portion_size: <class 'fiftyone.core.fields.StringField'>
#   weight_before: <class 'fiftyone.core.fields.IntField'>
#   weight_after: <class 'fiftyone.core.fields.IntField'>
#   yoloe_segmentation: <class 'fiftyone.core.fields.EmbeddedDocumentField'>
#   dinov2-image-embeddings: <class 'fiftyone.core.fields.VectorField'>
#   dinov2-vitl4-embeddings: <class 'fiftyone.core.fields.VectorField'>
#   kcal_before: <class 'fiftyone.core.fields.FloatField'>
#   kj_before: <class 'fiftyone.core.fields.FloatField'>
#   fat_before: <class 'fiftyone.core.fields.FloatField'>
#   saturated_fat_before: <class 'fiftyone.core.fields.FloatField'>
#   carbohydrates_before: <class 'fiftyone.core.fields.FloatField'>
#   sugar_before: <class 'fiftyone.core.fields.FloatField'>
#   protein_before: <class 'fiftyone.core.fields.FloatField'>
#   salt_before: <class 'fiftyone.core.fields.FloatField'>
#   kcal_after: <class 'fiftyone.core.fields.IntField'>
#   kj_after: <class 'fiftyone.core.fields.IntField'>
#   fat_after: <class 'fiftyone.core.fields.IntField'>
#   saturated_fat_after: <class 'fiftyone.core.fields.IntField'>
#   carbohydrates_after: <class 'fiftyone.core.fields.IntField'>
#   sugar_after: <class 'fiftyone.core.fields.IntField'>
#   protein_after: <class 'fiftyone.core.fields.IntField'>
#   salt_after: <class 'fiftyone.core.fields.IntField'>
#
# Dataset 2 fields:
#   id: <class 'fiftyone.core.fields.ObjectIdField'>
#   filepath: <class 'fiftyone.core.fields.StringField'>
#   tags: <class 'fiftyone.core.fields.ListField'>  --> element types (sample):
#   metadata: <class 'fiftyone.core.fields.EmbeddedDocumentField'>
#   created_at: <class 'fiftyone.core.fields.DateTimeField'>
#   last_modified_at: <class 'fiftyone.core.fields.DateTimeField'>
#   split: <class 'fiftyone.core.fields.StringField'>
#   bonid: <class 'fiftyone.core.fields.IntField'>
#   bon_id: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): int
#   article_number: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): int
#   ingredient_name: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): str
#   piece_article: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): str
#   number_of_portions: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): int
#   weight_per_portion: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): float
#   weight_per_plate: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): float
#   kcal_per_plate: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): float
#   kj_per_plate: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): float
#   fat_per_plate: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): float
#   saturated_fat_per_plate: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): float
#   carbohydrates_per_plate: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): float
#   sugar_per_plate: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): float
#   protein_per_plate: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): float
#   salt_per_plate: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): float
#   return_quantity: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): float
#   return_percentage: <class 'fiftyone.core.fields.ListField'>  --> element types (sample): float
#   dish: <class 'fiftyone.core.fields.StringField'>
#   portion_size: <class 'fiftyone.core.fields.StringField'>
#   weight_before: <class 'fiftyone.core.fields.IntField'>
#   kcal_before: <class 'fiftyone.core.fields.FloatField'>
#   kj_before: <class 'fiftyone.core.fields.FloatField'>
#   fat_before: <class 'fiftyone.core.fields.FloatField'>
#   saturated_fat_before: <class 'fiftyone.core.fields.FloatField'>
#   carbohydrates_before: <class 'fiftyone.core.fields.FloatField'>
#   sugar_before: <class 'fiftyone.core.fields.FloatField'>
#   protein_before: <class 'fiftyone.core.fields.FloatField'>
#   salt_before: <class 'fiftyone.core.fields.FloatField'>
#   weight_after: <class 'fiftyone.core.fields.IntField'>
#   kcal_after: <class 'fiftyone.core.fields.IntField'>
#   kj_after: <class 'fiftyone.core.fields.IntField'>
#   fat_after: <class 'fiftyone.core.fields.IntField'>
#   saturated_fat_after: <class 'fiftyone.core.fields.IntField'>
#   carbohydrates_after: <class 'fiftyone.core.fields.IntField'>
#   sugar_after: <class 'fiftyone.core.fields.IntField'>
#   protein_after: <class 'fiftyone.core.fields.IntField'>
#   salt_after: <class 'fiftyone.core.fields.IntField'>
#   yoloe_segmentation: <class 'fiftyone.core.fields.EmbeddedDocumentField'>
#   dinov2-image-embeddings: <class 'fiftyone.core.fields.VectorField'>
#   dinov2-vitl4-embeddings: <class 'fiftyone.core.fields.VectorField'>

# %%
# Inspect first few 'kcal_per_plate' values
for sample in dataset1.take(5):
    print(sample.kcal_per_plate)
# Out:
# ['56,050', '36,400', '18,800', '127,040', '9,150', '29,400', '82,600']
# ['129,960', '36,400', '18,800', '42,000', '90,090']
# ['129.96', '28', '3.5', '31.5', '204.3']
# ['98,4', '18,2', '85', '144,72', '11,1']
# ['56,050', '36,400', '18,800', '82,600', '90,090']

# %%
import re

def euro_or_us_str_to_float(x):
    if x is None or (isinstance(x, str) and x.strip() == ''):
        return None
    if isinstance(x, (int, float)):
        return float(x)
    x = x.strip()
    # If both comma and dot: dot is thousands, comma is decimal
    if ',' in x and '.' in x:
        x = x.replace('.', '').replace(',', '.')
    # Only comma: treat comma as decimal
    elif ',' in x:
        x = x.replace(',', '.')
    # Only dot: treat dot as decimal
    # else: already standard
    try:
        return float(x)
    except Exception:
        return None

# %%
field = 'kcal_per_plate'
temp_field = f"{field}_tmp"

# 1. Set first value for schema inference
for sample in dataset1:
    vals = getattr(sample, field, None)
    if isinstance(vals, list) and any(v not in (None, '', []) for v in vals):
        sample[temp_field] = [euro_or_us_str_to_float(v) for v in vals]
        sample.save()
        break

# 2. Assign for all samples
for sample in dataset1:
    vals = getattr(sample, field, None)
    if isinstance(vals, list):
        sample[temp_field] = [euro_or_us_str_to_float(v) for v in vals]
        sample.save()

# 3. Delete old field and rename tmp to original
dataset1.delete_sample_field(field)
dataset1.rename_sample_field(temp_field, field)

# %%
for sample in dataset1.take(5):
    print(sample.kcal_per_plate)
# Out:
# [68.4, 64.0, 186.3, 33.6]
# [129.96, 24.5, 82.6, 172.92]
# [56.05, 64.0, 82.6, 172.92]
# [173.6, 251.2]
# [129.96, 45.6, 42.0, 109.2]

# %%
import fiftyone as fo

# List all fields you want to harmonize to lists of floats
fields_to_convert = [
    "weight_per_portion",
    "weight_per_plate",
    "kcal_per_plate",
    "kj_per_plate",
    "fat_per_plate",
    "saturated_fat_per_plate",
    "carbohydrates_per_plate",
    "sugar_per_plate",
    "protein_per_plate",
    "salt_per_plate",
    "return_quantity",
    "return_percentage",
]

def euro_or_us_str_to_float(x):
    if x is None or (isinstance(x, str) and x.strip() == ''):
        return None
    if isinstance(x, (int, float)):
        return float(x)
    x = x.strip()
    # If both comma and dot: dot is thousands, comma is decimal
    if ',' in x and '.' in x:
        x = x.replace('.', '').replace(',', '.')
    elif ',' in x:
        x = x.replace(',', '.')
    # If only dot: already standard float
    try:
        return float(x)
    except Exception:
        return None

def convert_list_field_to_floats(dataset, field):
    tmp_field = field + "_tmp"
    # 1. Set the first (non-None) value for schema inference
    for sample in dataset:
        vals = getattr(sample, field, None)
        if isinstance(vals, list) and any(v not in (None, '', []) for v in vals):
            sample[tmp_field] = [euro_or_us_str_to_float(v) for v in vals]
            sample.save()
            break
    # 2. Assign for all samples
    for sample in dataset:
        vals = getattr(sample, field, None)
        if isinstance(vals, list):
            sample[tmp_field] = [euro_or_us_str_to_float(v) for v in vals]
            sample.save()
    # 3. Delete old field and rename tmp to original
    dataset.delete_sample_field(field)
    dataset.rename_sample_field(tmp_field, field)

# Run batch conversion on all relevant fields
for field in fields_to_convert:
    print(f"Converting field: {field}")
    convert_list_field_to_floats(dataset1, field)

print("All specified list fields in dataset1 are now lists of floats!")
# Out:
# Converting field: weight_per_portion
# Converting field: weight_per_plate
# Converting field: kcal_per_plate
# Converting field: kj_per_plate
# Converting field: fat_per_plate
# Converting field: saturated_fat_per_plate
# Converting field: carbohydrates_per_plate
# Converting field: sugar_per_plate
# Converting field: protein_per_plate
# Converting field: salt_per_plate
# Converting field: return_quantity
# Converting field: return_percentage
# All specified list fields in dataset1 are now lists of floats!

# %%
existing_paths = set(sample.filepath for sample in dataset1)
num_added = 0
for sample in dataset2:
    if sample.filepath in existing_paths:
        continue
    new_sample = sample.copy()
    new_sample.id = None
    dataset1.add_sample(new_sample)
    num_added += 1

print(f"Added {num_added} samples from dataset2 to dataset1.")
# Out:
# Added 255 samples from dataset2 to dataset1.

# %%
dataset1.name = "merged_food_dataset"
dataset1.save()
print("Renamed dataset to:", dataset1.name)
# Out:
# Renamed dataset to: merged_food_dataset

# %%
output_dir = "/content/drive/MyDrive/FoodWasteHackathon_BIBI/Dataset/food_waste_part_nerged"

dataset1.export(
    export_dir=output_dir,
    dataset_type=fo.types.FiftyOneDataset ,
    export_media=True
)
print(f"Dataset exported to: {output_dir}")
# Out:
# Exporting samples...
# INFO:fiftyone.utils.data.exporters:Exporting samples...
#  100% |████████████████████| 630/630 [7.9m elapsed, 0s remaining, 1.9 docs/s]
# INFO:eta.core.utils: 100% |████████████████████| 630/630 [7.9m elapsed, 0s remaining, 1.9 docs/s]
# Dataset exported to: /content/drive/MyDrive/FoodWasteHackathon_BIBI/Dataset/food_waste_part_nerged

# %% [markdown]
# ## Upload to hugging face

# %%
# 1. Install requirements (if not already installed)
# !pip install huggingface_hub --quiet

# %%
from google.colab import userdata
hf_token=userdata.get('HF_token')

# %%
# 2. Set up your Hugging Face token (assumes `keys` dict with 'hf_token')
from huggingface_hub import HfApi



# 4. Import FiftyOne and load your dataset
import fiftyone as fo

# (Assuming your dataset is already loaded/merged into `dataset1`)
# If not, load it here:
# dataset1 = fo.Dataset.from_dir(...)

# 5. Push to Hugging Face with push_to_hub
from fiftyone.utils.huggingface import push_to_hub

# Specify your Hugging Face repo: "username/dataset-name"
repo_id = "food-waste-dataset5"  # CHANGE this to your username/repo

push_to_hub(
    dataset1,
    repo_id,
    license="mit",      # or any SPDX license, e.g., "cc-by-4.0"
    exist_ok=True,      # allow updating the dataset if it already exists
    chunk_size=100,     # tune this if you have a very large dataset
    token=hf_token      # use your programmatic token
)

print(f"Dataset uploaded to: https://huggingface.co/datasets/{repo_id}")
# Out:
# Directory '/tmp/tmp13z6qbi9' already exists; export will be merged with existing files
# WARNING:fiftyone.core.collections:Directory '/tmp/tmp13z6qbi9' already exists; export will be merged with existing files
# Exporting samples...
# INFO:fiftyone.utils.data.exporters:Exporting samples...
#  100% |████████████████████| 630/630 [9.7s elapsed, 0s remaining, 78.1 docs/s]
# INFO:eta.core.utils: 100% |████████████████████| 630/630 [9.7s elapsed, 0s remaining, 78.1 docs/s]
# Uploading media files in 14 batches of size 100: 100%|██████████| 14/14 [01:49<00:00,  7.82s/it]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     408     try:
# --> 409         response.raise_for_status()
#     410     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/datasets/shahabdaiani/food-waste-dataset5/preupload/main
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# /tmp/ipython-input-1362870352.py in <cell line: 0>()
#      17 repo_id = "food-waste-dataset5"  # CHANGE this to your username/repo
#      18
# ---> 19 push_to_hub(
#      20     dataset1,
#      21     repo_id,
#
# /usr/local/lib/python3.11/dist-packages/fiftyone/utils/huggingface.py in push_to_hub(dataset, repo_name, description, license, tags, private, exist_ok, dataset_type, min_fiftyone_version, label_field, frame_labels_field, token, preview_path, chunk_size, **data_card_kwargs)
#     257         **data_card_kwargs,
#     258     )
# --> 259     card.push_to_hub(repo_id)
#     260
#     261
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/repocard.py in push_to_hub(self, repo_id, token, repo_type, commit_message, commit_description, revision, create_pr, parent_commit)
#     278             tmp_path = Path(tmpdir) / constants.REPOCARD_NAME
#     279             tmp_path.write_text(str(self), encoding="utf-8")
# --> 280             url = upload_file(
#     281                 path_or_fileobj=str(tmp_path),
#     282                 path_in_repo=constants.REPOCARD_NAME,
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/hf_api.py in _inner(self, *args, **kwargs)
#    1663
#    1664         # Otherwise, call the function normally
# -> 1665         return fn(self, *args, **kwargs)
#    1666
#    1667     _inner.is_future_compatible = True  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/hf_api.py in upload_file(self, path_or_fileobj, path_in_repo, repo_id, token, repo_type, revision, commit_message, commit_description, create_pr, parent_commit, run_as_future)
#    4702         )
#    4703
# -> 4704         commit_info = self.create_commit(
#    4705             repo_id=repo_id,
#    4706             repo_type=repo_type,
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/hf_api.py in _inner(self, *args, **kwargs)
#    1663
#    1664         # Otherwise, call the function normally
# -> 1665         return fn(self, *args, **kwargs)
#    1666
#    1667     _inner.is_future_compatible = True  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/hf_api.py in create_commit(self, repo_id, operations, commit_message, commit_description, token, repo_type, revision, create_pr, num_threads, parent_commit, run_as_future)
#    4231         _warn_on_overwriting_operations(operations)
#    4232
# -> 4233         self.preupload_lfs_files(
#    4234             repo_id=repo_id,
#    4235             additions=additions,
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/hf_api.py in preupload_lfs_files(self, repo_id, additions, token, repo_type, revision, create_pr, num_threads, free_memory, gitignore_content)
#    4457         if len(additions_no_upload_mode) > 0:
#    4458             try:
# -> 4459                 _fetch_upload_modes(
#    4460                     additions=additions_no_upload_mode,
#    4461                     repo_type=repo_type,
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/_commit_api.py in _fetch_upload_modes(additions, repo_type, repo_id, headers, revision, endpoint, create_pr, gitignore_content)
#     690             params={"create_pr": "1"} if create_pr else None,
#     691         )
# --> 692         hf_raise_for_status(resp)
#     693         preupload_info = _validate_preupload_info(resp.json())
#     694         upload_modes.update(**{file["path"]: file["uploadMode"] for file in preupload_info["files"]})
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     457                 " https://huggingface.co/docs/huggingface_hub/authentication"
#     458             )
# --> 459             raise _format(RepositoryNotFoundError, message, response) from e
#     460
#     461         elif response.status_code == 400:
#
# RepositoryNotFoundError: 401 Client Error. (Request ID: Root=1-688cc9c8-20e53e536415628549434e6b;33d05bc6-4ffe-4fd6-ba71-072e99c3b880)
#
# Repository Not Found for url: https://huggingface.co/api/datasets/shahabdaiani/food-waste-dataset5/preupload/main.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Invalid username or password.
# Note: Creating a commit assumes that the repo already exists on the Huggingface Hub. Please use `create_repo` if it's not the case.

# %%
from fiftyone.utils.huggingface import load_from_hub
recovered_dataset = load_from_hub('FoodWasteProjectBIBI/food_waste_merged_fiftyOneDS')
# Out:
# Downloading config file fiftyone.yml from FoodWasteProjectBIBI/food_waste_merged_fiftyOneDS
# INFO:fiftyone.utils.huggingface:Downloading config file fiftyone.yml from FoodWasteProjectBIBI/food_waste_merged_fiftyOneDS
# Loading dataset
# INFO:fiftyone.utils.huggingface:Loading dataset
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2334251941.py in <cell line: 0>()
#       1 from fiftyone.utils.huggingface import load_from_hub
# ----> 2 recovered_dataset = load_from_hub('FoodWasteProjectBIBI/food_waste_merged_fiftyOneDS')
#
# /usr/local/lib/python3.11/dist-packages/fiftyone/utils/huggingface.py in load_from_hub(repo_id, revision, split, splits, subset, subsets, max_samples, batch_size, num_workers, overwrite, persistent, name, token, config_file, **kwargs)
#     321         raise ValueError(f"Could not find fiftyone metadata for {repo_id}")
#     322
# --> 323     return _load_dataset_from_config(config, **kwargs)
#     324
#     325
#
# /usr/local/lib/python3.11/dist-packages/fiftyone/utils/huggingface.py in _load_dataset_from_config(config, **kwargs)
#     897         return _load_parquet_files_dataset_from_config(config, **kwargs)
#     898     else:
# --> 899         return _load_fiftyone_dataset_from_config(config, **kwargs)
#     900
#     901
#
# /usr/local/lib/python3.11/dist-packages/fiftyone/utils/huggingface.py in _load_fiftyone_dataset_from_config(config, **kwargs)
#    1498         dataset_kwargs["name"] = name
#    1499
# -> 1500     dataset = fod.Dataset.from_dir(download_dir, **dataset_kwargs)
#    1501
#    1502     if dataset_type_name != "FiftyOneDataset":
#
# /usr/local/lib/python3.11/dist-packages/fiftyone/core/dataset.py in from_dir(cls, dataset_dir, dataset_type, data_path, labels_path, name, persistent, overwrite, label_field, tags, dynamic, progress, **kwargs)
#    7065             a :class:`Dataset`
#    7066         """
# -> 7067         dataset = cls(name, persistent=persistent, overwrite=overwrite)
#    7068         dataset.add_dir(
#    7069             dataset_dir=dataset_dir,
#
# /usr/local/lib/python3.11/dist-packages/fiftyone/core/singletons.py in __call__(cls, name, _create, *args, **kwargs)
#      35         ):
#      36             instance = cls.__new__(cls)
# ---> 37             instance.__init__(name=name, _create=_create, *args, **kwargs)
#      38             name = instance.name  # `__init__` may have changed `name`
#      39         else:
#
# /usr/local/lib/python3.11/dist-packages/fiftyone/core/dataset.py in __init__(self, name, persistent, overwrite, _create, _virtual, **kwargs)
#     324
#     325         if _create:
# --> 326             doc, sample_doc_cls, frame_doc_cls = _create_dataset(
#     327                 self, name, persistent=persistent, **kwargs
#     328             )
#
# /usr/local/lib/python3.11/dist-packages/fiftyone/core/dataset.py in _create_dataset(obj, name, persistent, _patches, _frames, _clips, _src_collection)
#    8467     _src_collection=None,
#    8468 ):
# -> 8469     slug = _validate_dataset_name(name)
#    8470
#    8471     _id = ObjectId()
#
# /usr/local/lib/python3.11/dist-packages/fiftyone/core/dataset.py in _validate_dataset_name(name, skip)
#     133         clashing_name = clashing_name_doc["name"]
#     134         if clashing_name == name:
# --> 135             raise ValueError(f"Dataset name '{name}' is not available")
#     136         else:
#     137             raise ValueError(
#
# ValueError: Dataset name 'FoodWasteProjectBIBI/food_waste_merged_fiftyOneDS' is not available

# %%
recovered_dataset
